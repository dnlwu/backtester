# %%
from dataAccessor import get_intraday, get_daily, get_singletime
from config import av_api_key

# %%
df = get_daily('GOOG')
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#            date        open        high         low       close   adj_close  \
# 0    2004-08-19    2.490664    2.591785    2.390042    2.499133    2.499133
# 1    2004-08-20    2.515820    2.716817    2.503118    2.697639    2.697639
# 2    2004-08-23    2.758411    2.826406    2.716070    2.724787    2.724787
# 3    2004-08-24    2.770615    2.779581    2.579581    2.611960    2.611960
# 4    2004-08-25    2.614201    2.689918    2.587302    2.640104    2.640104
# ...         ...         ...         ...         ...         ...         ...
# 4778 2023-08-14  129.850006  131.910004  129.589996  131.830002  131.830002
# 4779 2023-08-15  131.589996  131.990005  129.819000  130.270004  130.270004
# 4780 2023-08-16  129.279999  130.897995  128.460007  129.110001  129.110001
# 4781 2023-08-17  130.449997  132.490997  129.850006  130.460007  130.460007
# 4782 2023-08-18  129.059998  129.830002  127.000000  128.110001  128.110001
#
#          volume ticker
# 0     897427216   GOOG
# 1     458857488   GOOG
# 2     366857939   GOOG
# 3     306396159   GOOG
# 4     184645512   GOOG
# ...         ...    ...
# 4778   17526200   GOOG
# 4779   14769200   GOOG
# 4780   17548400   GOOG
# 4781   23665600   GOOG
# 4782   23619400   GOOG
#
# [4783 rows x 8 columns]

# %%
df = get_intraday('GOOG')
df
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = get_intraday('GOOG')
#       2 df
#
# File X:\projects\backtester\dataAccessor.py:10, in get_intraday(ticker)
#       8 def get_intraday(ticker):
#       9     yf.pdr_override()
# ---> 10     raise NotImplementedError('TODO')
#
# NotImplementedError: TODO

# %%
df = get_singletime('GOOG','2023-08-18','open','daily')
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      ticker       date       price
# 4782   GOOG 2023-08-18  129.059998

# %%
import pandas as pd
test_orders = pd.DataFrame(
    [
        [1,'buy','open',pd.to_datetime('2023-04-05'),'IBM'],
        [2,'buy','open',pd.to_datetime('2023-03-08'),'IBM']
    ], 
    index = [1, 2],
    columns=['order_id','order_type','exec_time','exec_date','ticker']
)
test_orders
# Out:
#    order_id order_type exec_time  exec_date ticker
# 1         1        buy      open 2023-04-05    IBM
# 2         2        buy      open 2023-03-08    IBM

# %%
test_orders_mod = test_orders.copy()


test_orders_mod['fwd'] = test_orders.apply(lambda row: get_daily(row['ticker'],start_date=row['exec_date']), axis = 1)
test_orders_mod
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#    order_id order_type exec_time  exec_date ticker  \
# 1         1        buy      open 2023-04-05    IBM
# 2         2        buy      open 2023-03-08    IBM
#
#                                                  fwd
# 1              date        open        high      ...
# 2              date        open        high      ...

# %%
(
    pd.concat(test_orders_mod.set_index('order_id').pop('fwd').to_dict())
    .rename_axis(('order_id','new'))
    .reset_index(level=0)
    .reset_index(drop=True)
)
# Out:
#      order_id       date        open        high         low       close  \
# 0           1 2023-04-05  131.369995  132.610001  131.369995  132.139999
# 1           1 2023-04-06  132.160004  132.600006  130.320007  130.500000
# 2           1 2023-04-10  129.830002  131.080002  129.240005  131.029999
# 3           1 2023-04-11  130.580002  131.100006  130.179993  130.419998
# 4           1 2023-04-12  130.399994  130.889999  128.169998  128.539993
# ..        ...        ...         ...         ...         ...         ...
# 203         2 2023-08-14  143.050003  143.369995  141.800003  141.910004
# 204         2 2023-08-15  141.500000  142.309998  141.199997  141.869995
# 205         2 2023-08-16  141.699997  142.089996  140.559998  140.639999
# 206         2 2023-08-17  141.009995  142.660004  140.600006  140.660004
# 207         2 2023-08-18  140.000000  141.830002  139.759995  141.410004
#
#       adj_close   volume ticker
# 0    128.879318  2898700    IBM
# 1    127.279785  3050600    IBM
# 2    127.796707  2614400    IBM
# 3    127.201767  3132400    IBM
# 4    125.368141  3957500    IBM
# ..          ...      ...    ...
# 203  141.910004  4226400    IBM
# 204  141.869995  3656600    IBM
# 205  140.639999  3285300    IBM
# 206  140.660004  3742100    IBM
# 207  141.410004  3914700    IBM
#
# [208 rows x 9 columns]

# %%
test_orders_mod.set_index('order_id').pop('fwd')
# Out:
# order_id
# 1                date        open        high      ...
# 2                date        open        high      ...
# Name: fwd, dtype: object

# %%
# get_daily('IBM',start_date=pd.to_datetime('2023-04-05'),end_date = pd.to_datetime('2023-04-05') + pd.DateOffset(days=30))
test_out = test_orders.apply(lambda row: get_daily(row['ticker'],start_date=row['exec_date']), axis = 1)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
test_out[1]
# Out:
#             date        open        high         low       close   adj_close  \
# 15420 2023-04-05  131.369995  132.610001  131.369995  132.139999  128.879318
# 15421 2023-04-06  132.160004  132.600006  130.320007  130.500000  127.279785
# 15422 2023-04-10  129.830002  131.080002  129.240005  131.029999  127.796707
# 15423 2023-04-11  130.580002  131.100006  130.179993  130.419998  127.201759
# 15424 2023-04-12  130.399994  130.889999  128.169998  128.539993  125.368141
# ...          ...         ...         ...         ...         ...         ...
# 15509 2023-08-14  143.050003  143.369995  141.800003  141.910004  141.910004
# 15510 2023-08-15  141.500000  142.309998  141.199997  141.869995  141.869995
# 15511 2023-08-16  141.699997  142.089996  140.559998  140.639999  140.639999
# 15512 2023-08-17  141.009995  142.660004  140.600006  140.660004  140.660004
# 15513 2023-08-18  140.000000  141.830002  139.759995  141.410004  141.410004
#
#         volume ticker
# 15420  2898700    IBM
# 15421  3050600    IBM
# 15422  2614400    IBM
# 15423  3132400    IBM
# 15424  3957500    IBM
# ...        ...    ...
# 15509  4226400    IBM
# 15510  3656600    IBM
# 15511  3285300    IBM
# 15512  3742100    IBM
# 15513  3914700    IBM
#
# [94 rows x 8 columns]
